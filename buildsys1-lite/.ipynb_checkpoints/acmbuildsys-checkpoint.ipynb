# %%
import tensorflow as tf

# Load the Keras model
model = tf.keras.models.load_model("models/cnn_image_classification_model.h5")

# Convert to TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save TFLite model
with open("models/cnn_image_classification_model.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# 2025-07-23 16:27:17.815002: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-23 16:27:17.815535: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-23 16:27:17.818742: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-23 16:27:17.827403: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753306037.842044  665234 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753306037.846291  665234 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1753306037.857509  665234 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753306037.857522  665234 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753306037.857523  665234 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753306037.857524  665234 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-23 16:27:17.861719: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/farjad/.local/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-07-23 16:27:19.750293: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# INFO:tensorflow:Assets written to: /tmp/tmp23mqw24b/assets
# INFO:tensorflow:Assets written to: /tmp/tmp23mqw24b/assets
# Saved artifact at '/tmp/tmp23mqw24b'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name='conv2d_9_input')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   124041274565904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124041274569744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124041274568592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124041274570512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124041274572048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124041274572240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124041274571088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124041274571472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124041272542608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124041272543760: TensorSpec(shape=(), dtype=tf.resource, name=None)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1753306040.565394  665234 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1753306040.565414  665234 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-07-23 16:27:20.565902: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp23mqw24b
# 2025-07-23 16:27:20.566440: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-07-23 16:27:20.566448: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmp23mqw24b
# I0000 00:00:1753306040.573792  665234 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# 2025-07-23 16:27:20.574678: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-07-23 16:27:20.671030: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmp23mqw24b
# 2025-07-23 16:27:20.681213: I tensorflow/cc/saved_model/loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 115314 microseconds.
# 2025-07-23 16:27:20.695762: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.

# %%
ls
# Out:
# acmbuildsys.ipynb  Images100/    models/     requirements.txt
# edgeOps.sh         inference.py  monitor.py  supplementary_data_for_paper.zip

# %%
cd models/
# Out:
# /home/farjad/Desktop/ACMSE Material buildsys/models
# /home/farjad/.local/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
cd..
# Out:
#   Cell In[6], line 1
#     cd..
#        ^
# SyntaxError: invalid syntax

# %%
import tensorflow as tf

# Load the Keras model
model = tf.keras.models.load_model("models/cnn_image_classification_model.h5")

# Create converter
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Enable dynamic range quantization
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Convert the model
quantized_model = converter.convert()

# Save the quantized model
with open("models/cnn_image_classification_model_quantized.tflite", "wb") as f:
    f.write(quantized_model)

print("Quantized model saved.")
# Out:
# /home/farjad/.local/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# INFO:tensorflow:Assets written to: /tmp/tmpp4q9l7a1/assets
# INFO:tensorflow:Assets written to: /tmp/tmpp4q9l7a1/assets
# Saved artifact at '/tmp/tmpp4q9l7a1'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name='conv2d_9_input')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   124040068152976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124040068152592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124040068694480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124040068695824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124040068695440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124040068696592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124040068696784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124040068697552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124040068696208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124040068699280: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Quantized model saved.
# W0000 00:00:1753306219.408668  665234 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1753306219.408683  665234 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-07-23 16:30:19.408845: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpp4q9l7a1
# 2025-07-23 16:30:19.409381: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-07-23 16:30:19.409389: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpp4q9l7a1
# 2025-07-23 16:30:19.414181: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-07-23 16:30:19.511732: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpp4q9l7a1
# 2025-07-23 16:30:19.522096: I tensorflow/cc/saved_model/loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 113257 microseconds.

# %%
pwd
# Out:
# '/home/farjad/Desktop/ACMSE Material buildsys/models'

# %%
cd ..
# Out:
# /home/farjad/Desktop/ACMSE Material buildsys

# %%
ls
# Out:
# acmbuildsys.ipynb  Images100/    models/     requirements.txt
# edgeOps.sh         inference.py  monitor.py  supplementary_data_for_paper.zip

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import random

# Load the TFLite model
interpreter = tf.lite.Interpreter(model_path="models/cnn_image_classification_model.tflite")
interpreter.allocate_tensors()

# Get input/output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

def preprocess_image(image_path):
    img = image.load_img(image_path, target_size=(150, 150))  # Adjust if needed
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img /= 255.0
    return img.astype(np.float32)

def predict_single_image(image_path):
    img = preprocess_image(image_path)
    interpreter.set_tensor(input_details[0]['index'], img)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    return "Positive" if output[0][0] > 0.5 else "Negative"

def main(input_path):
    if os.path.isfile(input_path):
        print("Input should be a directory containing images.")
        return
        
    elif os.path.isdir(input_path):
        num_iterations = 1
        batch_size = 100
        all_predictions = []
        
        for _ in range(num_iterations):
            batch_predictions = []
            files = os.listdir(input_path)
            random.shuffle(files)
            for i, filename in enumerate(files):
                if filename.lower().endswith((".jpg", ".jpeg", ".png")):
                    image_path = os.path.join(input_path, filename)
                    predicted_class = predict_single_image(image_path)
                    batch_predictions.append((filename, predicted_class))
                    if (i + 1) % batch_size == 0:
                        break
            all_predictions.append(batch_predictions)
            print(batch_predictions)
            print("--------------------------------------")
        
    else:
        print("Invalid input path.")

input_path = os.path.join(os.getcwd(), 'Images100')  # test folder path
main(input_path)
# Out:
# /home/farjad/.local/lib/python3.12/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# [('35_00906.jpg', 'Negative'), ('00326.jpg', 'Positive'), ('320_00385.jpg', 'Negative'), ('00130.jpg', 'Positive'), ('44_00286.jpg', 'Negative'), ('00120.jpg', 'Positive'), ('315_00568.jpg', 'Negative'), ('00137.jpg', 'Positive'), ('80_00455.jpg', 'Negative'), ('376_00741.jpg', 'Negative'), ('00057.jpg', 'Positive'), ('49_00245.jpg', 'Negative'), ('00082.jpg', 'Positive'), ('00133.jpg', 'Positive'), ('27_00734.jpg', 'Negative'), ('00331.jpg', 'Positive'), ('00087.jpg', 'Positive'), ('122_00454.jpg', 'Negative'), ('136_00646.jpg', 'Negative'), ('00044.jpg', 'Positive'), ('99_00910.jpg', 'Negative'), ('33_00913.jpg', 'Negative'), ('00084.jpg', 'Positive'), ('00083.jpg', 'Positive'), ('21_00536.jpg', 'Negative'), ('00045.jpg', 'Positive'), ('00093.jpg', 'Positive'), ('105_00093.jpg', 'Negative'), ('129_00859.jpg', 'Negative'), ('00335.jpg', 'Positive'), ('00323.jpg', 'Positive'), ('00079.jpg', 'Positive'), ('00241.jpg', 'Positive'), ('332_00178.jpg', 'Negative'), ('00068.jpg', 'Positive'), ('00108.jpg', 'Positive'), ('00097.jpg', 'Positive'), ('00121.jpg', 'Positive'), ('00325.jpg', 'Positive'), ('00069.jpg', 'Positive'), ('00086.jpg', 'Positive'), ('65_00133.jpg', 'Negative'), ('00040.jpg', 'Positive'), ('00118.jpg', 'Positive'), ('00050.jpg', 'Positive'), ('00309.jpg', 'Positive'), ('00322.jpg', 'Positive'), ('00096.jpg', 'Positive'), ('00324.jpg', 'Positive'), ('12_00330.jpg', 'Negative'), ('158_00281.jpg', 'Negative'), ('00041.jpg', 'Positive'), ('00132.jpg', 'Positive'), ('00131.jpg', 'Positive'), ('108_00044.jpg', 'Negative'), ('00054.jpg', 'Positive'), ('00078.jpg', 'Positive'), ('00332.jpg', 'Positive'), ('117_00252.jpg', 'Negative'), ('00092.jpg', 'Positive'), ('210_00862.jpg', 'Negative'), ('00109.jpg', 'Positive'), ('00046.jpg', 'Positive'), ('63_00641.jpg', 'Negative'), ('94_00045.jpg', 'Negative'), ('103_00939.jpg', 'Negative'), ('147_00444.jpg', 'Negative'), ('00090.jpg', 'Positive'), ('00134.jpg', 'Positive'), ('326_00434.jpg', 'Negative'), ('00085.jpg', 'Positive'), ('00333.jpg', 'Positive'), ('00135.jpg', 'Positive'), ('240_00056.jpg', 'Negative'), ('00043.jpg', 'Positive'), ('111_00285.jpg', 'Negative'), ('00296.jpg', 'Positive'), ('00327.jpg', 'Positive'), ('68_00643.jpg', 'Negative'), ('00337.jpg', 'Positive'), ('50_00480.jpg', 'Negative'), ('307_00781.jpg', 'Negative'), ('334_00622.jpg', 'Negative'), ('153_00256.jpg', 'Negative'), ('00336.jpg', 'Positive'), ('86_00247.jpg', 'Negative'), ('00047.jpg', 'Positive'), ('00123.jpg', 'Positive'), ('00052.jpg', 'Positive'), ('92_00737.jpg', 'Negative'), ('00330.jpg', 'Positive'), ('00051.jpg', 'Positive'), ('14_00442.jpg', 'Negative'), ('00091.jpg', 'Positive'), ('00440.jpg', 'Positive'), ('301_00964.jpg', 'Negative'), ('00242.jpg', 'Positive'), ('237_00081.jpg', 'Negative'), ('00053.jpg', 'Positive'), ('00055.jpg', 'Negative')]
# --------------------------------------

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import random

# Load the TFLite model
interpreter = tf.lite.Interpreter(model_path="models/cnn_image_classification_model_quantized.tflite")
interpreter.allocate_tensors()

# Get input/output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

def preprocess_image(image_path):
    img = image.load_img(image_path, target_size=(150, 150))  # Adjust if needed
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img /= 255.0
    return img.astype(np.float32)

def predict_single_image(image_path):
    img = preprocess_image(image_path)
    interpreter.set_tensor(input_details[0]['index'], img)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    return "Positive" if output[0][0] > 0.5 else "Negative"

def main(input_path):
    if os.path.isfile(input_path):
        print("Input should be a directory containing images.")
        return
        
    elif os.path.isdir(input_path):
        num_iterations = 1
        batch_size = 100
        all_predictions = []
        
        for _ in range(num_iterations):
            batch_predictions = []
            files = os.listdir(input_path)
            random.shuffle(files)
            for i, filename in enumerate(files):
                if filename.lower().endswith((".jpg", ".jpeg", ".png")):
                    image_path = os.path.join(input_path, filename)
                    predicted_class = predict_single_image(image_path)
                    batch_predictions.append((filename, predicted_class))
                    if (i + 1) % batch_size == 0:
                        break
            all_predictions.append(batch_predictions)
            print(batch_predictions)
            print("--------------------------------------")
        
    else:
        print("Invalid input path.")

input_path = os.path.join(os.getcwd(), 'Images100')  # test folder path
main(input_path)
# Out:
# [('122_00454.jpg', 'Negative'), ('00052.jpg', 'Positive'), ('00045.jpg', 'Positive'), ('00051.jpg', 'Positive'), ('129_00859.jpg', 'Negative'), ('00096.jpg', 'Positive'), ('00047.jpg', 'Positive'), ('237_00081.jpg', 'Negative'), ('65_00133.jpg', 'Negative'), ('92_00737.jpg', 'Negative'), ('00242.jpg', 'Positive'), ('00054.
import os
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import random
from memory_profiler import profile
from memory_profiler import memory_usage
import joblib
from sklearn.preprocessing import StandardScaler
from skimage import io, color, feature
from skimage.transform import resize

# Load the trained model
model = tf.keras.models.load_model("models/cnn_image_classification_model.h5")


def preprocess_image(image_path):
    img = image.load_img(image_path, target_size=(150, 150))
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img /= 255.0
    return img

#kNN, logistic
#def preprocess_image(image_path):
#    image = io.imread(image_path)
#    if len(image.shape) == 3 and image.shape[-1] == 4:
#        image = image[:, :, :3]
#    img = resize(image, output_shape=(227,227))
#    img = (img - np.min(img)) / (np.max(img) - np.min(img)) * 255
#    img_gray = color.rgb2gray(img)
#    hog_features = feature.hog(img_gray, block_norm='L2-Hys', pixels_per_cell=(16, 16))
#    img = hog_features.reshape(1, -1)
#    return img


#@profile
def calling_decorators(image_path):
    img = preprocess_image(image_path)
    prediction =  model.predict(img)
    return prediction

def predict_single_image(image_path):
    prediction = calling_decorators(image_path)
    if prediction[0][0] > 0.5:
        return "Positive"
    else:
        return "Negative"

def main(input_path):
    if os.path.isfile(input_path):
        print("Input should be a directory containing images.")
        return
        
    elif os.path.isdir(input_path):
        num_iterations = 1
        batch_size = 100
        all_predictions = []
        
        for _ in range(num_iterations):
            batch_predictions = []
            files = os.listdir(input_path)
            random.shuffle(files)
            for i, filename in enumerate(files):
                if filename.endswith(".jpg") or filename.endswith(".jpeg") or filename.endswith(".png"):
                    image_path = os.path.join(input_path, filename)
                    predicted_class = predict_single_image(image_path)
                    batch_predictions.append((filename, predicted_class))
                    if (i + 1) % batch_size == 0:
                        break
            all_predictions.append(batch_predictions)
            print("--------------------------------------")
        
    else:
        print("Invalid input path.")

input_path = os.path.join(os.getcwd(), 'Images100')  # for test data
main(input_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# --------------------------------------

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import random
# Optional: uncomment if you want memory profiling
# from memory_profiler import profile

# Load the trained Keras model
model = tf.keras.models.load_model("models/cnn_image_classification_model.h5")

def preprocess_image(image_path):
    """Load and preprocess an image for the CNN model."""
    img = image.load_img(image_path, target_size=(150, 150))
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = img / 255.0  # Normalize to [0,1]
    return img

#@profile  # Optional: uncomment to profile memory
def calling_decorators(image_path):
    img = preprocess_image(image_path)
    prediction = model.predict(img, verbose=0)
    return prediction

def predict_single_image(image_path):
    prediction = calling_decorators(image_path)
    return "Positive" if prediction[0][0] > 0.5 else "Negative"

def main(input_path):
    """Classify all images in a given folder."""
    if os.path.isfile(input_path):
        print("Input should be a directory containing images.")
        return

    elif os.path.isdir(input_path):
        num_iterations = 1
        batch_size = 100
        all_predictions = []

        for _ in range(num_iterations):
            batch_predictions = []
            files = os.listdir(input_path)
            random.shuffle(files)
            for i, filename in enumerate(files):
                if filename.lower().endswith((".jpg", ".jpeg", ".png")):
                    image_path = os.path.join(input_path, filename)
                    predicted_class = predict_single_image(image_path)
                    batch_predictions.append((filename, predicted_class))
                    print(f"{filename}: {predicted_class}")
                    if (i + 1) % batch_size == 0:
                        break
            all_predictions.append(batch_predictions)
            print("--------------------------------------")

    else:
        print("Invalid input path.")

# Run the pipeline
input_path = os.path.join(os.getcwd(), 'Images100')  # Adjust if needed
main(input_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
#